# %% [markdown]
# # US - Baby Names

# %% [markdown]
# ### Introduction:
#
# We are going to use a subset of [US Baby Names](https://www.kaggle.com/kaggle/us-baby-names) from Kaggle.
# In the file it will be names from 2004 until 2014
#
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called baby_names.

# %%
baby_names=pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv')

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
baby_names.head(10)
# Out:
#    Unnamed: 0     Id      Name  Year Gender State  Count
# 0       11349  11350      Emma  2004      F    AK     62
# 1       11350  11351   Madison  2004      F    AK     48
# 2       11351  11352    Hannah  2004      F    AK     46
# 3       11352  11353     Grace  2004      F    AK     44
# 4       11353  11354     Emily  2004      F    AK     41
# 5       11354  11355   Abigail  2004      F    AK     37
# 6       11355  11356    Olivia  2004      F    AK     33
# 7       11356  11357  Isabella  2004      F    AK     30
# 8       11357  11358    Alyssa  2004      F    AK     29
# 9       11358  11359    Sophia  2004      F    AK     28

# %% [markdown]
# ### Step 5. Delete the column 'Unnamed: 0' and 'Id'

# %%
baby_names.drop(['Unnamed: 0','Id'],axis=1)
# Out:
#             Name  Year Gender State  Count
# 0           Emma  2004      F    AK     62
# 1        Madison  2004      F    AK     48
# 2         Hannah  2004      F    AK     46
# 3          Grace  2004      F    AK     44
# 4          Emily  2004      F    AK     41
# ...          ...   ...    ...   ...    ...
# 1016390     Seth  2014      M    WY      5
# 1016391  Spencer  2014      M    WY      5
# 1016392     Tyce  2014      M    WY      5
# 1016393   Victor  2014      M    WY      5
# 1016394   Waylon  2014      M    WY      5
#
# [1016395 rows x 5 columns]

# %% [markdown]
# ### Step 6. Is there more male or female names in the dataset?

# %%
baby_names['Gender'].value_counts()
#More female
# Out:
# Gender
# F    558846
# M    457549
# Name: count, dtype: int64

# %% [markdown]
# ### Step 7. Group the dataset by name and assign to names

# %%
names=baby_names.groupby('Name')

# %% [markdown]
# ### Step 8. How many different names exist in the dataset?

# %%
names.nunique()
#17632 different names
# Out:
#          Unnamed: 0   Id  Year  Gender  State  Count
# Name
# Aaban             2    2     2       1      1      1
# Aadan             4    4     3       1      2      3
# Aadarsh           1    1     1       1      1      1
# Aaden           196  196     9       1     45     43
# Aadhav            1    1     1       1      1      1
# ...             ...  ...   ...     ...    ...    ...
# Zyra              7    7     5       1      3      4
# Zyrah             2    2     2       1      2      2
# Zyren             1    1     1       1      1      1
# Zyria            10   10     7       1      3      3
# Zyriah            9    9     8       1      3      5
#
# [17632 rows x 6 columns]

# %% [markdown]
# ### Step 9. What is the name with most occurrences?

# %%
names.nunique().sort_values(by='Count', ascending=False).head()
#Emma is the name with most occurence
# Out:
#          Unnamed: 0   Id  Year  Gender  State  Count
# Name
# Emma            566  566    11       2     51    399
# Michael         578  578    11       2     51    397
# Jacob           568  568    11       2     51    395
# Ethan           567  567    11       2     51    392
# Olivia          566  566    11       2     51    373

# %% [markdown]
# ### Step 10. How many different names have the least occurrences?

# %%
name1=names.nunique().sort_values(by='Count')
name1[name1['Count']==name1['Count'].min()]
#Therea re 4836 different names with the least occurence
# Out:
#              Unnamed: 0  Id  Year  Gender  State  Count
# Name
# Aaban                 2   2     2       1      1      1
# Nyala                 1   1     1       1      1      1
# Elijio                1   1     1       1      1      1
# Nyamal                1   1     1       1      1      1
# Elijahjames           1   1     1       1      1      1
# ...                 ...  ..   ...     ...    ...    ...
# Airlie                2   2     2       1      1      1
# Soloman               3   3     3       1      2      1
# Solyana               1   1     1       1      1      1
# Solon                 1   1     1       1      1      1
# Adalay                1   1     1       1      1      1
#
# [4836 rows x 6 columns]

# %% [markdown]
# ### Step 11. What is the median name occurrence?

# %%
names.Count.median().to_frame()
# Out:
#          Count
# Name
# Aaban      6.0
# Aadan      5.5
# Aadarsh    5.0
# Aaden     10.0
# Aadhav     6.0
# ...        ...
# Zyra       6.0
# Zyrah      5.5
# Zyren      6.0
# Zyria      6.0
# Zyriah     6.0
#
# [17632 rows x 1 columns]

# %% [markdown]
# ### Step 12. What is the standard deviation of names?

# %%
names.Count.std().to_frame()
# Out:
#              Count
# Name
# Aaban     0.000000
# Aadan     0.957427
# Aadarsh        NaN
# Aaden    21.154974
# Aadhav         NaN
# ...            ...
# Zyra      1.154701
# Zyrah     0.707107
# Zyren          NaN
# Zyria     0.737865
# Zyriah    1.666667
#
# [17632 rows x 1 columns]

# %% [markdown]
# ### Step 13. Get a summary with the mean, min, max, std and quartiles.

# %%
names.describe()
# Out:
#         Unnamed: 0                                                     \
#              count          mean           std        min         25%
# Name
# Aaban          2.0  3.866900e+06  1.463004e+03  3865866.0  3866383.25
# Aadan          4.0  1.789515e+06  2.181189e+06   691905.0   694243.50
# Aadarsh        1.0  1.728030e+06           NaN  1728030.0  1728030.00
# Aaden        196.0  2.831898e+06  1.615565e+06   147897.0  1364269.50
# Aadhav         1.0  7.096060e+05           NaN   709606.0   709606.00
# ...            ...           ...           ...        ...         ...
# Zyra           7.0  2.505571e+06  2.273476e+06   556978.0   563486.00
# Zyrah          2.0  2.743536e+06  3.097243e+06   553455.0  1648495.75
# Zyren          1.0  5.074229e+06           NaN  5074229.0  5074229.00
# Zyria         10.0  2.978703e+06  1.704179e+06  1238175.0  1467783.50
# Zyriah         9.0  3.794022e+06  1.709386e+06  1238450.0  2137371.00
#
# ...

# %%
names[['Year','Count']].describe()
# Out:
#           Year                                                           \
#          count         mean       std     min      25%     50%      75%
# Name
# Aaban      2.0  2013.500000  0.707107  2013.0  2013.25  2013.5  2013.75
# Aadan      4.0  2009.750000  2.872281  2008.0  2008.00  2008.5  2010.25
# Aadarsh    1.0  2009.000000       NaN  2009.0  2009.00  2009.0  2009.00
# Aaden    196.0  2010.015306  2.044322  2005.0  2008.00  2010.0  2011.00
# Aadhav     1.0  2014.000000       NaN  2014.0  2014.00  2014.0  2014.00
# ...        ...          ...       ...     ...      ...     ...      ...
# Zyra       7.0  2012.142857  2.115701  2008.0  2011.50  2013.0  2013.50
# Zyrah      2.0  2012.000000  1.414214  2011.0  2011.50  2012.0  2012.50
# Zyren      1.0  2013.000000       NaN  2013.0  2013.00  2013.0  2013.00
# Zyria     10.0  2008.900000  2.685351  2005.0  2007.25  2008.0  2010.50
# Zyriah     9.0  2009.666667  2.915476  2006.0  2007.00  2009.0  2012.00
#
#                  Count
# ...
